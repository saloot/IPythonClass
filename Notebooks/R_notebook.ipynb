# %% [markdown]
# # R in Jupyter
#
# You can use notebooks for R as well.
#
# The R kernel can installed from [here](http://irkernel.github.io/).
#
# The full list of supported languages is [there](https://github.com/ipython/ipython/wiki/IPython-kernels-for-other-languages).

# %%
x <- 1 + 1  # a simple calculator
set.seed(123)
rnorm(5)  # boring random numbers
# Out:
# [1] -0.56047565 -0.23017749  1.55870831  0.07050839  0.12928774

# %%
par(mar = c(4, 4, 0.1, 0.1))
# Use mtcars data set, plot miles-per-gallon vs horse-power
with(mtcars, {
  plot(mpg ~ hp, pch = 20, col = "darkgray")
  lines(lowess(hp, mpg))
})
# Out:
# plot without title
