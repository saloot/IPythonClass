% %% [markdown]
% ## Matlab  <3
%
% Our favorite scientific software in a notebook!

% %%
t = 1:100;
plot(t/100, sin(2*pi*t/100));

% %% [markdown]
% It requires to have matlab installed on your system.

% %%
[XX,YY] = meshgrid(-5:0.1:5, -5:0.1:5);

mesh(XX, YY, XX.^2 + YY.^2)
